# %%
from ogdf_python import *

Tile_length = 100.0

cppinclude("ogdf/fileformats/GraphIO.h")
cppinclude("ogdf/basic/graph_generators/deterministic.h")
cppinclude("ogdf/fileformats/GraphIO.h")
cppinclude("ogdf/orthogonal/OrthoLayout.h")
cppinclude("ogdf/planarity/EmbedderMinDepthMaxFaceLayers.h")
cppinclude("ogdf/planarity/PlanarSubgraphFast.h")
cppinclude("ogdf/planarity/PlanarizationLayout.h")
cppinclude("ogdf/planarity/SubgraphPlanarizer.h")
cppinclude("ogdf/planarity/VariableEmbeddingInserter.h")

# cppinclude("ogdf/layered/SugiyamaLayout.h")

ogdf.EdgeArrow

G = ogdf.Graph()
ogdf.completeGraph(G, 16)
GA = ogdf.GraphAttributes(G, ogdf.GraphAttributes.all)
# define graph attributes
GA.directed=False

for n in G.nodes:
    GA.label[n] = "%s" % n.index()
    GA.width[n] = Tile_length
    GA.height[n] = Tile_length

for e in G.edges:
    GA.arrowType[e] =0

# SL = ogdf.PlanarizationLayout()
# SL.call(GA)
# GA

# Initialize layout components
pl = ogdf.PlanarizationLayout()
crossMin = ogdf.SubgraphPlanarizer()
ps = ogdf.PlanarSubgraphFast[int]()
ps.runs(100)
ves = ogdf.VariableEmbeddingInserter()
ves.removeReinsert(ogdf.RemoveReinsertType.All)

# Set up PlanarizationLayout components
crossMin.setSubgraph(ps)
crossMin.setInserter(ves)
pl.setCrossMin(crossMin)

# emb = ogdf.EmbedderMinDepthMaxFaceLayers()
# pl.setEmbedder(emb)

ol = ogdf.OrthoLayout()
ol.separation(10.0)
ol.cOverhang(10.0)

pl.setPlanarLayouter(ol)

pl.call(GA)
GA

# %%
pl.numberOfCrossings()
# Out:
# 588

# %%
ogdf.GraphIO.write(GA, "16_complete.gml")
# Out:
# True

# %%
def calculate_edge_length(edge):
    length = 0
    points = edge['graphics']['Line']
    for i in range(len(points) - 1):
        x1, y1 = points[i]['x'], points[i]['y']
        x2, y2 = points[i + 1]['x'], points[i + 1]['y']
        length += abs(x2 - x1) + abs(y2 - y1)
    return length


def read_x_y(line):
    # e.g., line = '\t\t\t\tpoint [ x 230.0000000000 y 540.0000000000 ]\n'
    # Extract x and y values without using re
    start_index = line.find('x') + 1
    end_index = line.find('y')
    x_str = line[start_index:end_index].strip()
    y_str = line[end_index + 1 : -3].strip()  # -3 to exclude the closing bracket and newline
    # Convert to float
    x = float(x_str)
    y = float(y_str)
    return(x, y)


with open('16_complete.gml', 'r') as file:
    lines = file.readlines()

edges = []
current_edge = None

for line in lines:
    if 'edge' in line:
        current_edge = {'graphics': {'Line': []}}
    elif 'source' in line and current_edge is not None:
        current_edge['source'] = int(line.split()[1])
    elif 'target' in line and current_edge is not None:
        current_edge['target'] = int(line.split()[1])
    elif (']' in line) and (current_edge is not None) and (not ('point' in line)):
        edges.append(current_edge)
        current_edge = None
    elif 'point' in line and current_edge is not None:
        # Extract coordinates of points in the line segment
        coordinates = read_x_y(line)
        point = {'x': coordinates[0], 'y': coordinates[1]}
        current_edge['graphics']['Line'].append( point)

edge_lengths=[]
for edge in edges:
    length = calculate_edge_length(edge)
    edge_lengths.append(length)
    print(f"Edge from {edge['source']} to {edge['target']} has length: {length}")
# Out:
# Edge from 0 to 1 has length: 945.8333333333001
# Edge from 0 to 2 has length: 1608.3333333331998
# Edge from 0 to 3 has length: 4281.2499999998
# Edge from 0 to 4 has length: 1064.5833333333999
# Edge from 0 to 5 has length: 647.9166666666999
# Edge from 0 to 6 has length: 522.9166666666999
# Edge from 0 to 7 has length: 1085.4166666666001
# Edge from 0 to 8 has length: 831.2499999999999
# Edge from 0 to 9 has length: 235.41666666679998
# Edge from 0 to 10 has length: 1210.4166666666001
# Edge from 0 to 11 has length: 870.8333333333001
# Edge from 0 to 12 has length: 695.8333333334001
# Edge from 0 to 13 has length: 2266.6666666669
# Edge from 0 to 14 has length: 902.0833333333001
# Edge from 0 to 15 has length: 439.58333333330006
# Edge from 1 to 2 has length: 535.4166666666001
# Edge from 1 to 3 has length: 999.9999999999002
# Edge from 1 to 4 has length: 354.1666666667
# Edge from 1 to 5 has length: 270.83333333340005
# Edge from 1 to 6 has length: 1243.7500000001
# Edge from 1 to 7 has length: 1520.8333333332996
# Edge from 1 to 8 has length: 918.7500000001002
# Edge from 1 to 9 has length: 564.5833333334
# Edge from 1 to 10 has length: 579.1666666666001
# Edge from 1 to 11 has length: 2245.8333333333003
# Edge from 1 to 12 has length: 56.24999999999994
# Edge from 1 to 13 has length: 937.4999999999999
# Edge from 1 to 14 has length: 681.2500000000001
# Edge from 1 to 15 has length: 339.58333333340005
# Edge from 2 to 3 has length: 391.6666666666001
# Edge from 2 to 4 has length: 408.3333333333
# Edge from 2 to 5 has length: 860.4166666667
# Edge from 2 to 6 has length: 2970.8333333334003
# Edge from 2 to 7 has length: 1239.5833333333003
# Edge from 2 to 8 has length: 2885.4166666666
# Edge from 2 to 9 has length: 1456.2499999999
# Edge from 2 to 10 has length: 500.00000000000006
# Edge from 2 to 11 has length: 3262.4999999999
# Edge from 2 to 12 has length: 747.9166666666
# Edge from 2 to 13 has length: 816.6666666666
# Edge from 2 to 14 has length: 825.0
# Edge from 2 to 15 has length: 1085.4166666667
# Edge from 3 to 4 has length: 837.5
# Edge from 3 to 5 has length: 1458.3333333332998
# Edge from 3 to 6 has length: 1372.9166666667
# Edge from 3 to 7 has length: 1060.4166666666
# Edge from 3 to 8 has length: 1239.5833333333
# Edge from 3 to 9 has length: 3408.3333333334
# Edge from 3 to 10 has length: 904.1666666665999
# Edge from 3 to 11 has length: 1714.5833333333
# Edge from 3 to 12 has length: 1214.5833333332998
# Edge from 3 to 13 has length: 820.8333333334001
# Edge from 3 to 14 has length: 1466.6666666666001
# Edge from 3 to 15 has length: 2445.8333333336
# Edge from 4 to 5 has length: 262.5
# Edge from 4 to 6 has length: 485.4166666665999
# Edge from 4 to 7 has length: 172.91666666670005
# Edge from 4 to 8 has length: 370.83333333329995
# Edge from 4 to 9 has length: 650.0
# Edge from 4 to 10 has length: 10.416666666700053
# Edge from 4 to 11 has length: 631.25
# Edge from 4 to 12 has length: 295.83333333329995
# Edge from 4 to 13 has length: 372.91666666670005
# Edge from 4 to 14 has length: 1304.1666666666001
# Edge from 4 to 15 has length: 679.1666666667
# Edge from 5 to 6 has length: 297.9166666665999
# Edge from 5 to 7 has length: 241.6666666666
# Edge from 5 to 8 has length: 156.24999999989984
# Edge from 5 to 9 has length: 233.33333333340016
# Edge from 5 to 10 has length: 268.74999999989996
# Edge from 5 to 11 has length: 1091.6666666667002
# Edge from 5 to 12 has length: 150.0
# Edge from 5 to 13 has length: 527.0833333334001
# Edge from 5 to 14 has length: 1189.5833333334
# Edge from 5 to 15 has length: 520.8333333334001
# Edge from 6 to 7 has length: 272.9166666666
# Edge from 6 to 8 has length: 106.24999999989984
# Edge from 6 to 9 has length: 350.00000000000006
# Edge from 6 to 10 has length: 464.5833333334002
# Edge from 6 to 11 has length: 312.5000000000001
# Edge from 6 to 12 has length: 668.75
# Edge from 6 to 13 has length: 627.0833333333
# Edge from 6 to 14 has length: 1770.8333333333
# Edge from 6 to 15 has length: 900.0
# Edge from 7 to 8 has length: 31.250000000000114
# Edge from 7 to 9 has length: 579.1666666666001
# Edge from 7 to 10 has length: 62.5
# Edge from 7 to 11 has length: 404.1666666666
# Edge from 7 to 12 has length: 602.0833333333001
# Edge from 7 to 13 has length: 233.3333333334
# Edge from 7 to 14 has length: 3974.9999999999004
# Edge from 7 to 15 has length: 2718.7499999999
# Edge from 8 to 9 has length: 391.66666666659995
# Edge from 8 to 10 has length: 177.08333333330006
# Edge from 8 to 11 has length: 422.9166666666001
# Edge from 8 to 12 has length: 547.9166666665999
# Edge from 8 to 13 has length: 402.0833333334001
# Edge from 8 to 14 has length: 2833.3333333334
# Edge from 8 to 15 has length: 1712.5000000000998
# Edge from 9 to 10 has length: 670.8333333332
# Edge from 9 to 11 has length: 833.3333333333001
# Edge from 9 to 12 has length: 304.16666666659995
# Edge from 9 to 13 has length: 912.5000000000001
# Edge from 9 to 14 has length: 1420.8333333333
# Edge from 9 to 15 has length: 329.16666666659995
# Edge from 10 to 11 has length: 587.4999999999999
# Edge from 10 to 12 has length: 558.3333333332998
# Edge from 10 to 13 has length: 172.91666666669994
# Edge from 10 to 14 has length: 1647.9166666667002
# Edge from 10 to 15 has length: 1252.0833333333
# Edge from 11 to 12 has length: 1918.75
# Edge from 11 to 13 has length: 647.9166666666999
# Edge from 11 to 14 has length: 1997.9166666666001
# Edge from 11 to 15 has length: 1714.5833333332
# Edge from 12 to 13 has length: 937.5
# Edge from 12 to 14 has length: 781.2499999999
# Edge from 12 to 15 has length: 204.16666666670005
# Edge from 13 to 14 has length: 1806.25
# Edge from 13 to 15 has length: 1610.4166666667
# Edge from 14 to 15 has length: 441.6666666667

# %%
Tile_real_length = 30 #[mm]
ratio=Tile_real_length/Tile_length
for i in range(len(edge_lengths)):
    edge_lengths[i]*=ratio

# %%
edge_lengths
# Out:
# [283.74999999999,
#  482.4999999999599,
#  1284.37499999994,
#  319.37500000001995,
#  194.37500000000998,
#  156.87500000000998,
#  325.62499999998005,
#  249.37499999999994,
#  70.62500000003999,
#  363.12499999998005,
#  261.24999999999,
#  208.75000000002004,
#  680.0000000000699,
#  270.62499999999,
#  131.87499999999002,
#  160.62499999998002,
#  299.99999999997004,
#  106.25000000000999,
#  81.25000000002001,
#  373.12500000003,
#  456.2499999999899,
#  275.62500000003,
#  169.37500000001998,
#  173.74999999998002,
#  673.7499999999901,
#  16.874999999999982,
#  281.24999999999994,
#  204.37500000000003,
#  101.87500000002001,
#  117.49999999998003,
#  122.49999999999,
#  258.12500000001,
#  891.2500000000201,
#  371.87499999999005,
#  865.62499999998,
#  436.87499999997,
#  150.0,
#  978.74999999997,
#  224.37499999998,
#  244.99999999998,
#  247.5,
#  325.62500000000995,
#  251.25,
#  437.49999999998994,
#  411.87500000000995,
#  318.12499999997993,
#  371.87499999999,
#  1022.5000000000199,
#  271.24999999997993,
#  514.37499999999,
#  364.37499999998994,
#  246.25000000002,
#  439.99999999998005,
#  733.7500000000799,
#  78.75,
#  145.62499999997996,
#  51.87500000001001,
#  111.24999999998998,
#  195.0,
#  3.1250000000100155,
#  189.375,
#  88.74999999998998,
#  111.87500000001002,
#  391.24999999998005,
#  203.75000000001,
#  89.37499999997996,
#  72.49999999998,
#  46.87499999996995,
#  70.00000000002005,
#  80.62499999996999,
#  327.50000000001006,
#  45.0,
#  158.12500000002004,
#  356.87500000002,
#  156.25000000002004,
#  81.87499999998,
#  31.87499999996995,
#  105.00000000000001,
#  139.37500000002007,
#  93.75000000000003,
#  200.625,
#  188.12499999998997,
#  531.24999999999,
#  270.0,
#  9.375000000000034,
#  173.74999999998002,
#  18.75,
#  121.24999999997999,
#  180.62499999999002,
#  70.00000000002,
#  1192.49999999997,
#  815.62499999997,
#  117.49999999997998,
#  53.12499999999002,
#  126.87499999998003,
#  164.37499999997996,
#  120.62500000002002,
#  850.0000000000199,
#  513.7500000000299,
#  201.24999999996,
#  249.99999999999,
#  91.24999999997998,
#  273.75,
#  426.24999999999,
#  98.74999999997998,
#  176.24999999999997,
#  167.49999999998994,
#  51.87500000000998,
#  494.37500000001,
#  375.62499999999,
#  575.625,
#  194.37500000000998,
#  599.37499999998,
#  514.37499999996,
#  281.25,
#  234.37499999997,
#  61.25000000001001,
#  541.875,
#  483.12500000000995,
#  132.50000000001]

# %%
from statistics import mean
mean(edge_lengths)
# Out:
# 288.6979166666635

# %%
max(edge_lengths)
# Out:
# 1284.37499999994
